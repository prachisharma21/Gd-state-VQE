# %% [markdown]
# # Project: To map the phase space for Mixed-field Ising model

# %% [markdown]
# Mixed-field Ising hamiltonian is given by
#
# \begin{equation}
# H= J \sum_{\langle ij \rangle} Z_i Z_j + h_x \sum_i X_i + h_z \sum_i Z_i,
# \end{equation}
# where $J = +1$ and $J = -1$ corresponds to anti-ferromagnetic and ferromagnetic phase. $h_x$ and $h_z$ corresponds the transverse and longitudinal applied field. You can find more details about the model and VQE ansatz built here in https://arxiv.org/pdf/2404.09132

# %% [markdown]
# Considered lattices in the code are based on the native qubit connective of the devices used for simulation for example quito and Guadalupe backends. The images are shown below

# %%
# need to install some packages to run the code
# best would be to create a conda env and install the packages below in that env
# qiskit==0.45.1                   
# qiskit-aer ==  0.13.2
# qutip
# scipy 
# numpy
# matplotlib for plotting

# %%
from qiskit.visualization import plot_gate_map 
from qiskit.providers.fake_provider import FakeQuitoV2, FakeGuadalupeV2 
# this is for Quito device
plot_gate_map(FakeQuitoV2())

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# this is for Guadalupe
plot_gate_map(FakeGuadalupeV2())

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Once you are familiarized with code, you can construct different lattices.

# %% [markdown]
# ## Todo
# The phase diagram is discussed in the following two papers
# 1. https://journals.aps.org/prb/abstract/10.1103/PhysRevB.108.134301 Fig:1
# 2. https://journals.aps.org/prb/abstract/10.1103/PhysRevB.68.214406 Fig:1
#
#
# For different values of $h_x$, $h_z$ (keeping J = 1): Try to plot a color map (something like below) of energy difference given by $\epsilon = E_{exact} - E_{VQE}$
#
# Here x-axis would be $h_x$ and y-axis as $h_z$ and color denote different values of $\epsilon$

# %% [markdown]
# ![image.png](attachment:image.png)
